# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./sample_data/linege-stock-data.csv')

# %% [markdown]
# ###예시 가설: 검색량의 분산이 높을수록 가격 변화량이 커질 것

# %%
df[:12].describe()
#3개월치 , 1분기
# Out:
#        num_search
# count   12.000000
# mean    30.833333
# std      4.569331
# min     26.000000
# 25%     27.000000
# 50%     29.500000
# 75%     33.000000
# max     39.000000

# %%
df[12:24].describe()
#3~6월 , 2분기
# Out:
#        num_search
# count   12.000000
# mean    32.083333
# std      5.142662
# min     24.000000
# 25%     28.500000
# 50%     32.500000
# 75%     35.500000
# max     40.000000

# %%
df[24:36].describe()
#3분기
# Out:
#        num_search
# count   12.000000
# mean    46.750000
# std     24.353924
# min     30.000000
# 25%     30.750000
# 50%     33.000000
# 75%     63.250000
# max    100.000000

# %%
df[36:].describe()
#4분기
# Out:
#        num_search
# count   16.000000
# mean    37.312500
# std      6.799203
# min     26.000000
# 25%     33.000000
# 50%     35.000000
# 75%     40.250000
# max     50.000000

# %% [markdown]
# ###가설과 분석한 결과를 발표하기

# %% [markdown]
# ###1. 가설: 엔씨의 새 게임이 출시될 때 마다 주가가 상승할 것이다.
#
# => 가설이 틀렸다!

# %%
df = pd.read_csv('./sample_data/linege-stock-data.csv')

# %%
df.head()
# Out:
#          date  num_search stock_price
# 0  2021-03-21          38     932,000
# 1  2021-03-28          39     834,000
# 2  2021-04-04          36     885,000
# 3  2021-04-11          31     906,000
# 4  2021-04-18          32     894,000

# %%
df2 = pd.read_csv('./sample_data/stock_.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-23-634e5cc9265b> in <module>()
# ----> 1 df2 = pd.read_csv('./sample_data/stock_.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-68302b2f4bd0> in <module>()
# ----> 1 df2.head()
#
# NameError: name 'df2' is not defined

# %%
df.head()
# Out:
#          date  num_search stock_price
# 0  2021-03-21          38     932,000
# 1  2021-03-28          39     834,000
# 2  2021-04-04          36     885,000
# 3  2021-04-11          31     906,000
# 4  2021-04-18          32     894,000

# %%
scores = np.array(df['num_search'])[:10]
scores
# Out:
# array([38, 39, 36, 31, 32, 27, 27, 26, 29, 26])
